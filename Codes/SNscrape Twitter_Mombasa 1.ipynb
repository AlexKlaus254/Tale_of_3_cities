# %% [markdown]
# Using snscrape to extract memes data from 3 kenyan cities for analysis in R (using R by choice)

# %%
#pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
#Tweets from Mombasa
scraper = sntwitter.TwitterSearchScraper('🤣 geocode:-4.0435,39.6682,1000km since:2022-04-01 until:2023-05-01')

# %%
tweet_data=[]
for i,tweet in enumerate(scraper.get_items()): 
    tweet_list=[tweet.date,
            tweet.id, 
            tweet.content,
            tweet.user.username,
            tweet.likeCount,
            tweet.retweetCount]
    tweet_data.append(tweet_list)
    if i==50000 :
        break
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_14288\532723744.py:5: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3d3ca6ac649f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e34aa43e99933f'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e36cc7f0caa0e7'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e314de444b0b61'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3bf923893e68a'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e30ada94a6c361'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3c9edd097ece6'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e33b79f535c8ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3d1fa38795e6d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3a3a6216bbb89'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e32ebcb864423c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e32032f31fdb8e'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3802c8c14aeff'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e3643f21b9992e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e39f6ad4bf0921'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e36476b5b2ac27'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e320607617f025'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3845be182cbea'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e32d7ca710aca6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3dddbf549cefe'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3f88b7d554cca'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3d4ffb4f54af7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3acfb17f32763'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e37e4c2af11fd8'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e3bd1767909393'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e36933ae48c57e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3de3cc59581d2'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3e528a2a84dca'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e323ebc5db075b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3511f7c2ffd0a'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3e0c615e54efe'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e39f4803d9189a'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3d119a7864a06'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e37e9720d8961d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e31f7bd0efa7f3'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3a31534060261'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3beb8f65c619a'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3cbde7e84528b'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3444b2c84e8b9'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e3994fb47ab8cd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e319bb875fc73f'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e387c142234f35'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3b6b309422b10'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e39f58df5ebfb2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e396cd8a3e3d08'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3b9cef5bad9f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3fd6a8ed928e3'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e3d2d440ea758c'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3960541a5c1d4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3339e2a4f0a90'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e34737a0ee2ccc'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3c77ee955130d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e35a30fabed381'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e34ca987dd9dde'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3fb634783f561'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3e48e7f3f04f4'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e32f385bff3244'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3bf202e6c43a0'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3a2a6f9c53b02'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3d2b3f94410d4'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e3993fe84d1efe'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3e91a551b4360'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3d24185a08b77'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e3401205347d54'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e32a0da55c1e0c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3a053eb33f83d'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e384dec6bdec94'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3b6c0f3f7b8cb'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e38ab85062b5d2'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e35fb30ef34ff1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e30903267b84ad'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e371d9825823ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e3fedfff489551'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3245675ee8545'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e30042dca1c941'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3fed49f7d631d'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3daa85554fc8e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e30f1c5d5cf037'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e37bf3da830e7b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3f926e6c7663e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e32ea3aab49ae1'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e33682363487ff'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e31ff7492f8ab0'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e392c2b38782fe'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3bb6c39117166'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e326b98808ccb4'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e381ad9e83766d'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e313598eb43475'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3990dd844590b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3da12df22d266'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3cc8c875ff5a9'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3de615208d7c9'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3a305402936fd'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e3f03fa6e9384a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3fdb123453920'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e392d9b66f6a79'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e32b7ce4762502'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e37146caaf4f89'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3295e8396f2b2'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e3249a77ad5060'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e332647f3e8349'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e34f928ef81cff'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3a450e7587c6c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e34f1e83616bda'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e346e706417864'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e361c4149e9f1b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3c5e9c9c4dfdc'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e397959a223c8b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3d6c0b7f543e2'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3856912c7766d'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e315356d26c8ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3c8a6c04ca596'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3f41cee8fef2b'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e3c508452b189b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e33d3423c16400'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e39be3df04f852'
# Skipping unrecognised entry ID: 'promoted-tweet-1664542366726799360-e329c17e559508'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3ab1b0c531863'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3c182b9a8cc91'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e345e7240cce93'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3bb3c05ec7728'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e3a87760300e12'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e303bcf9984a3e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3e54dc092ece1'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e3059d50b6e532'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e3476e6d83b838'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3fd5d4433747b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3452347125fc4'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e31517b7da2ae6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3dd0f4404c7b4'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e30d4943a85f34'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3be2771e75402'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e39b1c2f8931e3'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e3bc86cdea386e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e3f7d3c36e1ec1'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e353f9202aeca4'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3261ba93f7cd1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3d2dc604de4b0'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e35b7fbd26e034'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e39be5c400043b'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e32cb3319862b0'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e33cc865953976'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3e3af68bd66bf'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3a57c02edd520'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e348035b2e3d00'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3893f53e95ee9'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3552e2c22913e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e37aae45cbe226'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e32f1b49423189'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e39c0f0f02d0fa'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3b6ef819efaff'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e3dd2857519ddc'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3cb20ad00438d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3e3f0e90184b2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e370dfc60bf205'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e36d4b021fdca4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e35e4d6edbae51'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e30d572fbdf43d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e39a5d3fbbd17c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3a99df293e6a8'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e3cc6910292fb2'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e3dd0453a79a18'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e3a307d383005d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e33427b5f7eb36'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e31a679f619188'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e344e79f4d5e2b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e3f7626f8eabad'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e3889b561ea5ae'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e37f72fa23b342'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e32e330acd2b73'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e3ef46f8eaa0ad'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e460755fa41fcc'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4222082ecb4c4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4d6cc693fb22d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4222771c2c380'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4af9a058a4751'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e47cd347e2b905'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e469e345d12ffd'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e43e67413d1f05'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4174567ac2534'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e441d260e7dc3a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e467fb563a6e34'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4b60561fb079a'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e4f3154cdc90c8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4351229176e6b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e41dc4a06d633a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e42016e1b7e71e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4133836f47ee9'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e490e39b0cda02'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4566bbc4f7a91'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4aa7135943a0e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e48a48924c60ad'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e40a1ed6957dbe'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e440d58319ec65'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4e2a91649300d'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4166eeabdb5d6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4f4946dc3f8b0'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e494acb3e772ba'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4581a9af14766'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e48456185fbf12'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4ffd8c69d8f20'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4880728d5dec4'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e430c3229824d3'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e472b60b7f1e16'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e41b5abbed010e'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4ce66bc6abb6c'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e490585fcfa651'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4f3200e916ae0'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e45b3782fb518f'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e4f864d34cb4ec'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e44cd54b758bb5'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e411055d072a13'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e455866d380d13'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a7a2fa495ad0'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e415abe0683a17'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e415dc46dfb3ca'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e417c75c81a9b9'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4708f4e514845'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e45811df6fc338'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e425ec46273c69'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e439bc57e021ee'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e44b310fb1d582'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e43758507b39b3'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4ed702e28b236'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4fc3dbc6abdb3'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4b6e40815b243'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4a394517a31ea'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e42613630b30c1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4b02f3d16b01b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4cd6270c13f88'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e489f2b8e91487'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e48f70edd10646'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4be228ea19a0e'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4ad6f7f3b0e22'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e460ffdaa4fca8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e40a2d09d5fe1e'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e40aabc12791f6'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e4c88674088ffa'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e49ceb35809737'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e49a50d7c324c6'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4a7f978e70c6b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4de734c307456'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e45ad7f5bf3ccc'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e428d04a94c38c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4f6b27351d511'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e439595ba20fdc'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4ecf84e318907'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4f7b7958cf04f'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4fc8477f3e127'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e429f0da5813cf'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e47bee4acfa931'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e415bfc54a9c65'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e447ad97889ba0'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4f7c8f5ad4638'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e4605f96556f34'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4ff486022744c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e41ecd6416e576'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4dc38931dc87a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4d272ffcfb3e1'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4339b1d71dbba'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e49b5211fb61e4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a600589ff3a6'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e40fd5272ef68a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e45771988aeb34'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4f1c9010d4cdc'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4a7030773833e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4031e525a3ce2'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e43541cf212da2'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e41f7c814c7040'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4d6f6e247971e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4d1cb781def49'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e45fc9b5ec6b3c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e462d6a1e178c9'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e45c9786e429ae'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e4fe0d4434910d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4f39a4eff1a39'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4390b77002fe4'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e468b06d434dab'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e445f31efddd0d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4bfa3617706c5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4c5dfd7d5ddb3'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e44164ff5b9100'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e47596a67fc866'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a653fc7aa87c'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e47efd7d042627'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e463a924151716'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4a9e667a5b96e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4663ccc8b2f6c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4998f0b4d6eb8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e48f20c898c7b5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4bf1a8efc9d61'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e455eef32aad8c'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e40254776086c8'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e435d9f0923992'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e44277212c3816'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4a72a947953d9'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4f1677da15aeb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e432b683f0e2cc'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e44f2d091338a8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e42dfaa02f17e3'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e40ee4e1d0f433'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4f6aec5cb3979'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e430d9eb2b26ef'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e493baeb001e5a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e47e35dbe58eb4'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e42abdafb15b0e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e46d61b78943e1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e471599275c5fd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e46b15c86b6bb7'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e490efb22d1260'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4bf9162db61cf'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4ab048236e95d'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4cbb8973772cf'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e4278d44b7e2b6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e41a77d5711855'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e469efa1d9ed80'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e49a3b5d7ee5ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4177e55eafe08'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4a3cc72d224f8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e44f381e9fc2bb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4544b8034756b'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4a0fa5b3d890d'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4f1269d540f52'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4d526ce49c618'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e42be3ffe2db2e'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e4f78d684d17b0'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e47effce3374e0'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e493c94929dac2'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4ef87266de060'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e43d7833672bfb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4cfb3fb5358bd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4d2b31671d504'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e46451dfc3f298'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4b2478d0850f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4de49e052a6b8'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e4b21e27010d69'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e40d5d257e63dc'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e41254f2f36bfb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e44cb516e8d98a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e43b939b9bd634'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e407d240c7f67b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4a5f9561c3e10'
# Skipping unrecognised entry ID: 'promoted-tweet-1654771364916793346-e42e3258dbea97'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a37d4c82f428'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e44235cfafa385'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4224ad376fa22'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e460d973e3eca8'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e45911ba65387b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e460e03aed7960'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4f475ac0a4331'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e44ed4eb7376c5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e40c83671eb496'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4af679b98e460'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4ea0064734ca5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4037a3aa7cc33'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e41b0270731189'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e4fb1e22c125a2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4ae4d2b040344'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4e6ab3264e9f3'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e460c43d32afd9'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e43c5f232a0d12'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4b0b9a05ce191'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e40ff2d111d4f2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e45b2273f2dfcd'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4dabead311803'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4bf14b8509487'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4fc9195701df4'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4f8c2d9a13465'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4c37976bb9ee8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4074be637688b'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4aa46c450e3df'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e437cffb601752'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e45dd906c1f763'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e448fb7bfebdc5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e451768242667b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e464e3d2ad5323'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e48766ac762a1e'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4a50738ca5fe2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4bf87efab741b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4a3463cb4fff4'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4585baec281db'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4cdf39ab545a3'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4f2b3cb7fc0b7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e486baaf57c887'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e480fb2e3cb092'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e466fbd274ae5b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4d84cacd8121f'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e431e5072c7942'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e4dd271187f51b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a814210f805d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4fbf6738434ca'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e45ca44ee4e092'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4565cb3ec7738'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e49af3945d493d'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e42a7f29dee3db'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4030e78a083df'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4d27ccc33f2c5'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e44811a016b908'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4bc50c09b8993'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e444b30cabbad9'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e416bbfd75c5d9'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4c3c80bdb425d'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e45a438540ef3d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4e7663020e7df'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e445ba4f7adc5d'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e496343ed9897e'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4e1fb1e710fd0'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4581fa0afbdee'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4749df315b91a'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e40a0622b013ee'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4bf28cdb780b4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4b3d79c491bdf'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4c72e218f44eb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4c10ec23fa070'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4e4f73b706157'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4339d04b5a077'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e48204fca2a043'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e41a433c64c05b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e45b54a040104f'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4015c8d92259b'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4e829488c41dd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4e9ed1d4325cd'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e4782fbee172b8'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e4932a5cd7fccb'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4eb55e984aaf9'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4a839b784d6cd'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e46249cb9bd613'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e46dca4fc09f72'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-e48feabc927c48'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e4529c161d24e4'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4f00f4c09ec02'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e46bcebd5712f9'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e463d563c50aea'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e48a2414040f08'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e4af7935fd776e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e48a0428d60dd0'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e44628126b3ee3'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4f9a7b3c7b959'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e49220204bca48'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e424bf377ef26a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4bc6f6f5863bb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4eb99fe913db6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4ff8d6930f298'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e45c3632f0d681'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e47fec483f81f2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e45526365c3f73'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4384d06abecb0'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e427ddf3761351'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e478bc4564db9e'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e456c60db6866c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e4b306af1fcce7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e43e5d85322302'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e466737759072b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4a271f9562237'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e460b3ccd219bd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4ea6eab9bbf8a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e47c1948e2309f'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e4dbd838059c72'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e4b5402d38f24b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e4106c4e1debd5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e438f7086827ba'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e47b2084908469'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e4f6dc314def0b'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e52342a3c700dc'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5f827a2bcf597'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e51d26b6d224b1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5ea1eac675183'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e52bcf2c0df6d2'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5f41fbb26c19e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e57e9be33632fc'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5357032ef0d17'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e52ef9801794a2'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e54b564064e3c6'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e5c9906a765689'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5ed7d08c261a1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5105a608733d2'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e5fd3a2d72ccb9'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e55ad327040447'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e5d53611a81cff'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5c273af77ad9f'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e5c84982044025'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e56fa4c4e16fad'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e51e37f2e7eed8'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e565654a79246d'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e563d461790b3e'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e5c592920f3168'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e57c9a4629488e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e53ec85cb421d1'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5469831ee68b1'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5853c1016b581'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5de2164cd10a8'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e59aae256fdf93'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5392544befacb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5ce8a2c43f675'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e52ca7c049d537'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e5a1788e87da0d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5bcfdf966f28a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-e5b8d065b4f74b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5c24f50cf2ba6'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5ec5b6642f0bf'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e5d5711b9cdf62'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5e3664e0dcea4'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e560e01381a096'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e57982c9e86d92'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5fb638b130dbf'
# Skipping unrecognised entry ID: 'promoted-tweet-1664536961003008000-e5082b9a44cbf5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5cec8fc261fae'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e532d31e4b4865'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e5fc74bf2a0b36'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e554439afcbfec'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5ac7606b597fe'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e571fe160d90fa'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e50b925f3893e2'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e5b23480409b8b'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e5f84a3c83c92c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e57558042cc8c2'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e500a428039f7d'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e558b1a04a77c4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e516b2b9aa8594'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-e58cb749d1354d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e586e86f8f3627'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5d95c4105d66e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e58c5c75aa9e38'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5bb5fcbd48eca'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5377112f211ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e5af7f37e0a54a'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5f4e84bcab7a6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5d73a950dc672'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-e5c79860ba9db5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e57961d74e0048'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e50bae24b24919'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e513824ef5f6f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e58352e90b6555'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5147ce9c432db'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5f69068200c21'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e5feaa040b5eaa'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5a56fe5435e21'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e5a36d063e8a81'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5f7dc9466352c'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e579750cf71128'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e57113bfd341f0'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5f8131a144615'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5b32eb7d9dcbe'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e5d4228551f183'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5b8b9610796db'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e59881f504de73'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5840a81602d09'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-e510c49df4a682'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e567d60d4ba372'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e51f115df11dc4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5d7f4acf26d47'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5eb5fcaebc869'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5f0cab67f947b'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-e5e8666a4a9f21'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e54e6cea0aa09b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5afe0e67f6bb6'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e5f4348012cd44'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e54824b1c0779b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5fccca4d20007'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e5f76ecccc2326'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-e57547195c4607'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e5eb5ee8ebc9c6'
# Skipping unrecognised entry ID: 'promoted-tweet-1162310547909632000-e59241a2158feb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e52329d8fabd7f'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-e5db404c56874a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e50f10ff89d5ef'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-e540a19aee23c1'
# Skipping unrecognised entry ID: 'promoted-tweet-1164503528355835904-e58414dc7b3e58'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-e563d39d23017f'
# ...
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-eee244f447920d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-eef839eeeab569'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ee53fe16b8380c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-ee032d26c776da'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ee89cde42a3df7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ee232d26a35959'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ee6182b9c2baa9'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ee80f0a40675d5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef996c9f23085e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef78fcb0baaf43'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-ef5204044edc8d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef199301bdbd8d'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef17b20a61278d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efe027fa323a33'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef278e316bb572'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef5c48c8b044a9'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef8f490379753b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efde2441ca8c5a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-efb0f25d5e67b7'
# Skipping unrecognised entry ID: 'promoted-tweet-1659106546922528769-ef811fc11308b6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef57fc5636bf97'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef414d4725761d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efdea6017d1476'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef898aaaf44e44'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-ef244cc45f7033'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efd1fed4ab6743'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef9449be5ff4a0'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-efc522138dbd8d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef3cde7c360963'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efa5c54bc9c95a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef59b237ffbfa5'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef9731de49ca25'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef0d6254268581'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-ef550e95f8ca3e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efdb00a3b85721'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef891b780f6e9a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efbfe259d6152a'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-efeb8557a26fd0'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-ef1ca00eac8e68'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef9c12e8ac5079'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef186d46dce94b'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-efad96b9562ce9'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef2713e3551e0d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef269f92549caa'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-efd173c99af2e1'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef692bfe926997'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef8578f87896b1'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-efc0803db1f1ff'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef382fb7534153'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef7859b9442134'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef3ff41e02db14'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef72b043686e81'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-efa28ee4d86b78'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef85bf71b311bb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef1cc4735b0954'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-ef1aed7144eeea'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef9138dfa49ef4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef08cda00c1182'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef4d19db1df2ae'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef2333a022c3f8'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-ef10ca458cd70d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efb0d0397e44f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef68804c148130'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef57852d6b6c21'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-efe6e2d9135241'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef709a1a0142f0'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef93b3516d2038'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef45c12dfc454c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef45007ea3c2aa'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef3d8f693cb6af'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef5fe1f7f7d15f'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef48548915dd8e'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-efe60db399a2c1'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef33eefa277cb5'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef0fd9d75d5fb6'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-ef01a4599ac56e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef1ff671067bfd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efb3453f0e5acf'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-eff506bfb5017a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef4a378edc0524'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-effabb95e7e741'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef21eb113b4469'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef8f7f7d1fa92d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efed6d1bc4ed49'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-ef654f53de5319'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef4d059e0fd6b6'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efd7a48adf413a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661301778422349830-efd1a69b528e0e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-efa1bb84c1233e'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efad1fd40ecb47'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef85920bc25432'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efe4299ded45f7'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef19e95cc04181'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef90baa85f6dde'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef7b3358b5ad33'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef9906649a5daa'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-efb0fb2b5c2c95'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef0a4b02e6f6ef'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef2dda1b585011'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef56772a0fe039'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef029931a2afbb'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-efde64c96fa6a4'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef266096fb9c37'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef46e4e7cb54f4'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-ef612a32fc01ce'
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-ef03b7e7fe1acd'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef1dbcd43a6434'
# Skipping unrecognised entry ID: 'promoted-tweet-1654522274022555655-ef7c0d66b49ee4'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef3bdff6271c1b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef6a0e35951c3d'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-efe6d6a0fd99c2'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-efa1a8d52803c0'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef50d17258672e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-efac10807397b7'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef0242635cb4e1'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-efc63714cee01a'
# Skipping unrecognised entry ID: 'promoted-tweet-1661643262803730432-ef3cad60886540'
# Skipping unrecognised entry ID: 'promoted-tweet-1660661809416740868-ef0e4754700d02'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efb1cf4f1dde0c'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efce2404f2eb55'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-effb6b2df3ab97'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef4e90b509bbf5'
# Skipping unrecognised entry ID: 'promoted-tweet-1659091449298792448-ef1249f283a28d'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efcb1bf4960a3e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef06505c43d10b'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-efdd05277c8f48'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-efcda416ab63d6'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-ef7bf9a993c60a'
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef3f973c00e612'
# Skipping unrecognised entry ID: 'promoted-tweet-1663530699716960256-ef514b802f614e'
# Skipping unrecognised entry ID: 'promoted-tweet-1661723032375656448-efb6b618e34891'
# Twitter responded with an error: TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified, TimeoutError: Timeout: Unspecified
# Skipping unrecognised entry ID: 'promoted-tweet-1663201714403418114-ef8cc0cdd00e5e'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 tweet_data=[]
# ----> 2 for i,tweet in enumerate(scraper.get_items()):
#       3     tweet_list=[tweet.date,
#       4             tweet.id,
#       5             tweet.content,
#       6             tweet.user.username,
#       7             tweet.likeCount,
#       8             tweet.retweetCount]
#       9     tweet_data.append(tweet_list)
#
# File C:\ProgramData\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1695, in TwitterSearchScraper.get_items(self)
#    1692 paginationParams = {'variables': paginationVariables, 'features': features}
#    1694 for obj in self._iter_api_data('https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline', _TwitterAPIType.GRAPHQL, params, paginationParams, cursor = self._cursor, instructionsPath = ['data', 'search_by_raw_query', 'search_timeline', 'timeline', 'instructions']):
# -> 1695 	yield from self._graphql_timeline_instructions_to_tweets(obj['data']['search_by_raw_query']['search_timeline']['timeline']['instructions'])
#
# File C:\ProgramData\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1491, in _TwitterAPIScraper._graphql_timeline_instructions_to_tweets(self, instructions, includeConversationThreads, **kwargs)
#    1489 		_logger.warning(f'Skipping empty tweet entry {entry["entryId"]}')
#    1490 		continue
# -> 1491 	yield self._graphql_timeline_tweet_item_result_to_tweet(entry['content']['itemContent']['tweet_results']['result'], tweetId = tweetId, **kwargs)
#    1492 else:
#    1493 	_logger.warning('Got unrecognised timeline tweet item(s)')
#
# File C:\ProgramData\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1446, in _TwitterAPIScraper._graphql_timeline_tweet_item_result_to_tweet(self, result, tweetId, **kwargs)
#    1444 	raise snscrape.base.ScraperException(f'Unknown result type {result["__typename"]!r}')
#    1445 tweet = result['legacy']
# -> 1446 user = self._graphql_user_results_to_user(result['core']['user_results'], userId = int(result['legacy']['user_id_str']))
#    1447 if 'retweeted_status_result' in tweet:
#    1448 	#TODO Tombstones will cause a crash here.
#    1449 	kwargs['retweetedTweet'] = self._graphql_timeline_tweet_item_result_to_tweet(tweet['retweeted_status_result']['result'])
#
# File C:\ProgramData\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1605, in _TwitterAPIScraper._graphql_user_results_to_user(self, results, userId)
#    1603 kwargs = {}
#    1604 kwargs['blue'] = results['result']['is_blue_verified']
# -> 1605 if (labelO := results['result']['affiliates_highlighted_label'].get('label')):
#    1606 	kwargs['label'] = self._user_label_to_user_label(labelO)
#    1607 return self._user_to_user(results['result']['legacy'], id_ = userId if userId is not None else int(results['result']['rest_id']), **kwargs)
#
# KeyError: 'affiliates_highlighted_label'

# %%
tweet_data
# Out:
# [[datetime.datetime(2023, 4, 30, 22, 10, 43, tzinfo=datetime.timezone.utc),
#   1652797654613610497,
#   'Sacramento asking for water 🤣\n\n#NBA',
#   'Emanzi20',
#   4,
#   1],
#  [datetime.datetime(2023, 4, 30, 21, 19, 49, tzinfo=datetime.timezone.utc),
#   1652784845901135874,
#   '@Maziku07 Unanipanga sana 🤣',
#   'gcngo88',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 20, 41, 24, tzinfo=datetime.timezone.utc),
#   1652775180400316419,
#   "@nj3ry @ItsDevMutai I'm selling hope here. Don't ruin my story 🤣",
#   'AbadoJack',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 20, 40, 36, tzinfo=datetime.timezone.utc),
#   1652774980143263747,
#   '@Schwarzenegger Why are you playing with food?🤣 https://t.co/CFqBHmtAbv',
#   'BabiesLoyal',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 20, 18, tzinfo=datetime.timezone.utc),
#   1652769288917250048,
#   '🤣',
#   'BenonGowa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 20, 14, 9, tzinfo=datetime.timezone.utc),
#   1652768320993542146,
#   '@MchelseaTz 🤣 https://t.co/v8q06JGzo5',
#   'daudi10emmanuel',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 20, 4, 36, tzinfo=datetime.timezone.utc),
#   1652765920257867778,
#   '@MarekaMalili Uwanjani leo kulikuwa na kelele masikio yote nimetoka yanauma 🤣',
#   'ksn__14',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 59, 5, tzinfo=datetime.timezone.utc),
#   1652764531666321409,
#   '@Johnlaban256 @MaamaKampala21 You had no boots🤔🤔😂😂🤣',
#   'Aloysiuskayita',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 54, 40, tzinfo=datetime.timezone.utc),
#   1652763418032582657,
#   'Peace on my TL..akuna upuzi ya top of the table 🤣',
#   'paulo_thedon',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 51, 11, tzinfo=datetime.timezone.utc),
#   1652762543331368963,
#   "How long till he makes Chelsea's shortlist of managers? 🤣",
#   'paulo_thedon',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 39, 35, tzinfo=datetime.timezone.utc),
#   1652759623332507649,
#   "We're getting old 🤣 https://t.co/Crakvgh6Ch",
#   'Finmedicalscrub',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 23, 22, tzinfo=datetime.timezone.utc),
#   1652755540869521409,
#   'Hapa kwa nyumba Ni vita boss man @MajimajiKenya Btw who owns @IndomieKenya me and my son John 🤣\nCourtesy of #ChezaGospelKitengela \n@GhettoRadio895 \nIlikua Safi sana 👊 na tulibarikiwa\n#Brekko https://t.co/Uq370J9P86',
#   'Stevemulwa9',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 16, 10, tzinfo=datetime.timezone.utc),
#   1652753728519151616,
#   '@MarekaMalili From now on any post related to @yangasc1935 must be in English… 🤣',
#   'sangomussa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 10, 34, tzinfo=datetime.timezone.utc),
#   1652752322253012993,
#   '@_Screechy_ @omwambaKE 😂🤣',
#   'PhillipMacloud',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 10, 1, tzinfo=datetime.timezone.utc),
#   1652752181869654018,
#   '@KChichika Ramadhan brothers wedding 🤣',
#   'sangomussa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 9, 4, tzinfo=datetime.timezone.utc),
#   1652751943817674752,
#   '@JSiatumain @Vet_flomelly @Scientist_elly1 @SamuelRwanda111 @ProFarmHer @p_dusabimana @fogagric @DjetaPenemak @a_kilimo @eric_niyitanga @agriresearchclb @NAP_Africa Heh I thought that was only in Tz, Chigali!!! Africa ni Moja 🤣',
#   'sangomussa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 6, 18, tzinfo=datetime.timezone.utc),
#   1652751245059276800,
#   "Mbona yanga mmefuzu na hamna furaja what's wrong 🤣\n\n@Hon_KibayasiF",
#   'miraba_7',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 19, 1, 8, tzinfo=datetime.timezone.utc),
#   1652749945424732162,
#   '@WemaKako "Wish I was rich enough to have a golden penis cover" nimecheka hiyo comment 🤣',
#   'ZuwenaKhatib',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 54, 3, tzinfo=datetime.timezone.utc),
#   1652748165395763201,
#   '@Mule_Kaipambe Ah! 🤣',
#   'Hendrix_ChiChi',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 53, 4, tzinfo=datetime.timezone.utc),
#   1652747918154031105,
#   '@NgalulaDonald Soreeee 😄 🤣',
#   'kenkunde1',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 51, 8, tzinfo=datetime.timezone.utc),
#   1652747429115035649,
#   '@ktwels What is this defender doing? Anatafuta nini Nyasini...😱\U0001fae2\U0001fae3😂🤣 @MuhadiaNicks',
#   'Twashelilly',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 44, 51, tzinfo=datetime.timezone.utc),
#   1652745848206286849,
#   '@mustymosha buddah km hutaki embarrassment jenga wako, tumestiriwa tu hapo 🤣',
#   'singo_ar1',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 44, 49, tzinfo=datetime.timezone.utc),
#   1652745841692536833,
#   "@RufasKe Soon people of the mountain, we'll have beachfront property 👀😅🤣",
#   'ANdaihera',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 37, 2, tzinfo=datetime.timezone.utc),
#   1652743880452833282,
#   '@clarakimaro 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 30, 12, tzinfo=datetime.timezone.utc),
#   1652742162209988614,
#   '@Osama_otero Maisha Nairobi ikikushindaRudi ocha utaanza kusumbua sasa 🤣',
#   'jinakubwa001',
#   2,
#   1],
#  [datetime.datetime(2023, 4, 30, 18, 27, 17, tzinfo=datetime.timezone.utc),
#   1652741428684943360,
#   '@PBMureithi 😫😭🤣',
#   'ANdaihera',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 18, 4, 45, tzinfo=datetime.timezone.utc),
#   1652735757872709635,
#   ', 😂🤣',
#   'Liam254',
#   1,
#   1],
#  [datetime.datetime(2023, 4, 30, 18, 4, 6, tzinfo=datetime.timezone.utc),
#   1652735594538098690,
#   '@thebeeti Böyle bir desteğe ihtiyacım vardı 🤣💘',
#   'kymetwho',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 56, 52, tzinfo=datetime.timezone.utc),
#   1652733773295828996,
#   '@Gaviball__ @Churchez41 😂🤣',
#   'MichealLMarvin1',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 54, 2, tzinfo=datetime.timezone.utc),
#   1652733058368282625,
#   "You don't want that kind of partner, sis.\nYou just don't know it yet, trust me!\n🤣",
#   'adrianpmolo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 52, 6, tzinfo=datetime.timezone.utc),
#   1652732572571430915,
#   '@Kaliisainnocen2 @jalirabagi You and who bro 🤣',
#   'mkanoti',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 50, 19, tzinfo=datetime.timezone.utc),
#   1652732123717959682,
#   'Wameweka mkazooo 😂🤣 @Hon_KibayasiF',
#   'miraba_7',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 45, 49, tzinfo=datetime.timezone.utc),
#   1652730994368151552,
#   '@chubbyshix I checked out @ 60 minutes to go do other stuff. \nSaved my heart unnecessary stress I see 🤣\n\nTHE FIST PUMPS ARE BACK!! 🙌🏿',
#   'RitchieOdak',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 40, 40, tzinfo=datetime.timezone.utc),
#   1652729698017767425,
#   '@DullahTheking2 🤣',
#   'miraba_7',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 40, 29, tzinfo=datetime.timezone.utc),
#   1652729650676748292,
#   '@bajabiri 😅🤣 huku ndiko kuchanganyikiwq kwenyewe',
#   'atupele_benard',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 40, 12, tzinfo=datetime.timezone.utc),
#   1652729579960672256,
#   'I remember Arsenal fans saying "we don\'t care about FA cup we\'re only focusing on EPL title" 😂🤣 https://t.co/QvzFrIh7pD',
#   'UnaManutd',
#   19,
#   5],
#  [datetime.datetime(2023, 4, 30, 17, 40, 8, tzinfo=datetime.timezone.utc),
#   1652729563288334338,
#   "@Aurea_sereia Parceque vos grands frères gênent les mecs de faire ce qu'ils veulent 🤣",
#   'MakandzouSayouf',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 28, 45, tzinfo=datetime.timezone.utc),
#   1652726695760207873,
#   '@Kamardine_M @parisien_est Mais l’avez-vous lue au moins ? Si oui, l’avez-vous comprise, 🤣 ? Et si oui encore pourriez vous en citer un extrait intéressant ?',
#   'jugeClarence',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 19, 36, tzinfo=datetime.timezone.utc),
#   1652724394567901186,
#   '@TrollFootball 🤣',
#   'samih_st',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 14, 27, tzinfo=datetime.timezone.utc),
#   1652723098225876994,
#   "@InfluencerUg1 U didn't do math at A level 🤣",
#   'Davidkwilliam17',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 17, 4, 59, tzinfo=datetime.timezone.utc),
#   1652720717312434177,
#   '@ManUtdswahil Wampe golden glove yake mapema tu.. Hao wengine bado sana.. 🤣',
#   'jnzemya',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 59, 1, tzinfo=datetime.timezone.utc),
#   1652719214023655426,
#   "@Isaac_Kaumba23 It's alright 🤣",
#   'Hendrix_ChiChi',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 35, 44, tzinfo=datetime.timezone.utc),
#   1652713356577452034,
#   '@INFLUENCERjr 🤣😀😅',
#   'atupele_benard',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 35, 19, tzinfo=datetime.timezone.utc),
#   1652713250029547521,
#   '@fumbokhanJr 😅😀🤣',
#   'atupele_benard',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 34, 45, tzinfo=datetime.timezone.utc),
#   1652713109457362944,
#   '@kijumba_jr Daaah kila nikikukwepa nakutana nawe😀😅🤣🙌🙌',
#   'atupele_benard',
#   7,
#   1],
#  [datetime.datetime(2023, 4, 30, 16, 32, 2, tzinfo=datetime.timezone.utc),
#   1652712425425125379,
#   "@AganBright @_jumaallan @Kamala_Code254 I'm watching from afar 🤣",
#   'AbadoJack',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 31, 43, tzinfo=datetime.timezone.utc),
#   1652712346555412487,
#   '@iammwanjala 😅😀🤣 Manager hataki utani',
#   'atupele_benard',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 28, 15, tzinfo=datetime.timezone.utc),
#   1652711471120302084,
#   'Van deki.... 🤣 🤣 🤣 🤣 https://t.co/gvHVydEfB3',
#   'supasta45',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 7, 58, tzinfo=datetime.timezone.utc),
#   1652706368464224263,
#   '@CchezLarson @Belive_Kinuthia 🤣😅🤭\U0001fae2',
#   'Musymo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 16, 6, 16, tzinfo=datetime.timezone.utc),
#   1652705939613523968,
#   'Tottenham are useless 😂🤣',
#   'henrywahome',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 56, 58, tzinfo=datetime.timezone.utc),
#   1652703598214623232,
#   '@MadPeEngineer Ntakua navichapa kila siku hamna kupoa 🤣',
#   'iAmLyimo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 55, 13, tzinfo=datetime.timezone.utc),
#   1652703157007384579,
#   '@TheLoveDre 😜🤣.',
#   'IsaacImaka',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 49, 32, tzinfo=datetime.timezone.utc),
#   1652701729165647874,
#   'This is an absolutely different side 😅🤣',
#   'Y_carter',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 43, 15, tzinfo=datetime.timezone.utc),
#   1652700147938099200,
#   '@PresenterNoah Hyo silaha sas🤣😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 32, 18, tzinfo=datetime.timezone.utc),
#   1652697393270513664,
#   '@itsOsama_kareem 🤣😅😅 wale wa kamiti😥',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 15, 0, 49, tzinfo=datetime.timezone.utc),
#   1652689466857758720,
#   '@MogoiMark 🤣 https://t.co/jW4uR055Vw',
#   'JoelLan41919613',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 14, 19, 47, tzinfo=datetime.timezone.utc),
#   1652679143668981762,
#   '@ahmednasirlaw 😅🤣',
#   'kipmaxg',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 14, 18, 47, tzinfo=datetime.timezone.utc),
#   1652678891281043458,
#   '@kn9ts @carnversations @mbugua_SIunit Bado magari zao zimekwama Nyahururu. Mimi niko home 🤣',
#   'AbadoJack',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 14, 11, 52, tzinfo=datetime.timezone.utc),
#   1652677151592685570,
#   'He has done it again 🤣 Bruno💯',
#   'Eugene_KE001',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 59, 52, tzinfo=datetime.timezone.utc),
#   1652674131022827529,
#   '@Bexmusiq Son who broke your heart 🤣?!',
#   'HarrietNakalem2',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 50, 1, tzinfo=datetime.timezone.utc),
#   1652671651337625600,
#   "You don't rate us from makindye, huh?!!💀🤣",
#   'WeAreNtMatesBro',
#   4,
#   2],
#  [datetime.datetime(2023, 4, 30, 13, 47, tzinfo=datetime.timezone.utc),
#   1652670894127427584,
#   '@PresenterNoah Kashindikan kam Chelsea ilivyoshindika kupata ushind chin ya Lampard mpk sas😂🤣😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 41, 18, tzinfo=datetime.timezone.utc),
#   1652669458119262211,
#   '@Visitmbeya 🤣😀😅',
#   'atupele_benard',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 12, 58, tzinfo=datetime.timezone.utc),
#   1652662328989548545,
#   '@HeemMufc 🤣😅😅😅 finary🤣🤣😪😪😪',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 9, 55, tzinfo=datetime.timezone.utc),
#   1652661560681046020,
#   'In need of a baecation by the beach. Manifesting Namu in Watamu with Mfalme wangu. 🤣💛✨ https://t.co/cc1V1Wufgo',
#   'IhureNamugongo',
#   6,
#   0],
#  [datetime.datetime(2023, 4, 30, 13, 5, 12, tzinfo=datetime.timezone.utc),
#   1652660371017064450,
#   '@AchimapaKitgum 😁🤣😜😀😂',
#   'Payira',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 49, 41, tzinfo=datetime.timezone.utc),
#   1652656469446127616,
#   '@japhet_kapinga 🤣',
#   'rayasel94',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 47, 39, tzinfo=datetime.timezone.utc),
#   1652655955392311296,
#   '@delscopio @shobanes 🤣',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 47, 27, tzinfo=datetime.timezone.utc),
#   1652655907090644994,
#   '@Abigael_kabugho @bamwinejnr The kind of people I love to belong with 🤣',
#   'MosesB_X',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 44, 11, tzinfo=datetime.timezone.utc),
#   1652655083035795456,
#   "So while you're busy, I'll write a list of things I love about you 🤣 \nSimply because I wanna be stuck in your inbox",
#   'EllyMemes_',
#   8,
#   5],
#  [datetime.datetime(2023, 4, 30, 12, 40, 15, tzinfo=datetime.timezone.utc),
#   1652654092508884993,
#   '@oscarmoses19 He needs that of 15k 🤣',
#   'AnkwatseRitah',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 18, 34, tzinfo=datetime.timezone.utc),
#   1652648638483427329,
#   'Good afternoon @PHIAMAX 🤣 rais  wa kusema na ku... https://t.co/q3mEGYdCBe',
#   'CraigMan_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 13, 13, tzinfo=datetime.timezone.utc),
#   1652647290560032772,
#   'Nashindwa kumuelewa kipara 😅🤣',
#   'Y_carter',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 5, 5, tzinfo=datetime.timezone.utc),
#   1652645242120675328,
#   '@Darkmatazz @TMohamedSoilihi 🤣 ! La victoire de la Préfecture…. Bah voyons… RDV le 2 mai… salut 👋🏻… @Kamardine_M @DeputeeEstelle',
#   'jugeClarence',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 12, 3, tzinfo=datetime.timezone.utc),
#   1652644719040647172,
#   '@josekisukuli 🤣😀😅aibu naona mimi',
#   'atupele_benard',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 48, 23, tzinfo=datetime.timezone.utc),
#   1652641039297945601,
#   '@TeyaKevin Haka kataomba milango zifunguke. 🤣',
#   'Murakariuki',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 46, 28, tzinfo=datetime.timezone.utc),
#   1652640557967998978,
#   "@vianaindi1 These one's work too 🤣 https://t.co/wgBI4AIjOH",
#   'Andrey256_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 40, 56, tzinfo=datetime.timezone.utc),
#   1652639168349044737,
#   '@Vybzofficialug2 🤣',
#   'muwonge1990',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 32, 38, tzinfo=datetime.timezone.utc),
#   1652637078960721921,
#   '@kilundeezy 😪🤣',
#   'UzimaComrade',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 22, 49, tzinfo=datetime.timezone.utc),
#   1652634607043354624,
#   '@EcEssie 🤣😅😅 manboobs😥',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 16, 1, tzinfo=datetime.timezone.utc),
#   1652632896270659584,
#   'https://t.co/KReGYUoZDc\nUkisikia Ile “WAMEMCHOKOZA BEAR”\nSasa Huyu Ndio #BEAR Mwenyewe\nThe Man Behind The #NipeniMauaYangu Project 💐\n#NB  Ni Wamemchokoza Bear Sio Wamemchokoza MBEYA 🤣\nCc. @Roma_Mkatoliki\n#derdeedomedia #LeafsForever #ชาอึนอู #JungKook #JungKook #NotMyKing #fyp https://t.co/BMZ4zuh5vH',
#   'derdeedomedia',
#   4,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 15, 10, tzinfo=datetime.timezone.utc),
#   1652632681589493762,
#   '@PBMureithi @kamz26 True 🤣',
#   'ANdaihera',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 6, 58, tzinfo=datetime.timezone.utc),
#   1652630618402873345,
#   '@uYesuKrestu @pmcafrica For the love of potatoes 😨🤣',
#   'ronaldkasasa4',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 11, 2, tzinfo=datetime.timezone.utc),
#   1652629370207367169,
#   'Msipake na wanja sasa mnakaa kama waganga 😂😂😂🤣',
#   'AngelaJM0309',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 46, 25, tzinfo=datetime.timezone.utc),
#   1652625445882327040,
#   "Africa has started splitting, soon we'll have beach property 🤨😅🤣",
#   'ANdaihera',
#   4,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 40, 10, tzinfo=datetime.timezone.utc),
#   1652623873823629314,
#   '@PeshAhumuza Nowwaaaayyy 🤣🤣🤣🤣🤣\n\nLet’s practice: “Good belated Morning Pesh!” 🤣',
#   'AnitaKomukama',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 37, 20, tzinfo=datetime.timezone.utc),
#   1652623161379225601,
#   'Huna hata wa kukufanyia massage weekend 🤣 tofaut yako na ngedere ni mkia tu💀🚶🏽\u200d♂️',
#   '_Mrc_09',
#   6,
#   1],
#  [datetime.datetime(2023, 4, 30, 10, 36, 53, tzinfo=datetime.timezone.utc),
#   1652623045813587968,
#   '😆 😆 🤣',
#   'bsmbale',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 36, 19, tzinfo=datetime.timezone.utc),
#   1652622904465432579,
#   '@ChelseaDiva10 Sijui majibu anatoaga wapi 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 27, 10, tzinfo=datetime.timezone.utc),
#   1652620604305014784,
#   '@stangatimu 💀😹🤣',
#   'nderisarah',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 12, 1, tzinfo=datetime.timezone.utc),
#   1652616790017552384,
#   'Short sleeve shirts kutoka Turkey 🔥\n.\nBei: 23,000/=\n.\nSize: M-2XL\n.\nZipo chache sana, njoo Whatsapp Chap nifanye delivery 🛒👇\n.\nhttps://t.co/oJYPCt1EEC\n.\nMkoani unapokea ndani ya 24 hrs 🛒\n.\nDar ninafanya Fast Delivery 🛒🛍️\n.\nKindly Retweet 👇🤣\n.\n#NipeDili #SokoLetu https://t.co/qlFtWQSJbi',
#   'Dream_onlineshp',
#   8,
#   7],
#  [datetime.datetime(2023, 4, 30, 10, 7, 46, tzinfo=datetime.timezone.utc),
#   1652615719803076608,
#   'Your future husband 🤣 https://t.co/mhHCBdggkM',
#   'BraydenDak',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 5, 59, tzinfo=datetime.timezone.utc),
#   1652615271750721537,
#   '@Rivers_Swahili @Mzungu_pori1 Kule Casablanca atukuona Ujani Wala Njano Arzert 🤣',
#   'pasco_undole',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 10, 3, 21, tzinfo=datetime.timezone.utc),
#   1652614609243721729,
#   '@phan_wa_2 Kuna Mapenzi na kushabikia Arsanel 🤣',
#   'pasco_undole',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 59, 11, tzinfo=datetime.timezone.utc),
#   1652613560852180999,
#   '@_esteeam @NduruuMan @Acoco_ke @Bandit__2 @Deon_judas @JoeMmg1 @Keam_254 @kefini___ @MistaSkelter @NaiFynest @ThepemlinKee @muli_brian_ 🤣',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 53, 5, tzinfo=datetime.timezone.utc),
#   1652612024117895171,
#   '🤣😭',
#   'njoks_mungai',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 31, 59, tzinfo=datetime.timezone.utc),
#   1652606715378954240,
#   'If Uhuru had a third term, uthamakistan roads would all be tarmac to peoples compounds. While driving here I was wondering why Thika highway is not ending only to notice it’s been extended.🤣\n\nAlso, the climate and the ever green environment. Perfect.\n\nLucky people.',
#   'MissKwegah1',
#   80,
#   6],
#  [datetime.datetime(2023, 4, 30, 9, 27, 54, tzinfo=datetime.timezone.utc),
#   1652605689582305281,
#   "@nbstv Ye nga yafuna amabaati ng'ate siwe Karamoja 🤣?",
#   'SsekamamatteJ',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 17, 8, tzinfo=datetime.timezone.utc),
#   1652602978467979265,
#   '@UtdPlug If i speak i will be in trouble 🤣 https://t.co/LB1nMuEVBK',
#   'Alinhonewcastle',
#   5,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 12, 40, tzinfo=datetime.timezone.utc),
#   1652601853979381760,
#   "Hhoooo, No is the time\nEeeeh, this coldness won't be manageable 🤣",
#   'ElugetNavi',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 9, 2, 16, tzinfo=datetime.timezone.utc),
#   1652599234875588608,
#   '“Niko na pesa na ni ya Babako… Kaskie vibaya huko kwenyu..” \n#Hooked 💯 😂🤣😅',
#   'NyambuG',
#   7,
#   1],
#  [datetime.datetime(2023, 4, 30, 9, 1, 34, tzinfo=datetime.timezone.utc),
#   1652599062644899841,
#   '@chimamy153 @Kissaka0 Huyuu👉🐕🤣',
#   'pasco_undole',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 8, 54, 17, tzinfo=datetime.timezone.utc),
#   1652597227196391424,
#   'Was loneliness for me\n😄 🤣 😂',
#   'ShokiUg',
#   4,
#   1],
#  [datetime.datetime(2023, 4, 30, 8, 41, 21, tzinfo=datetime.timezone.utc),
#   1652593973041541120,
#   '@kamuyu_david @jumaf3 @WilliamsRuto 🤣😅🤣',
#   'GonaWaMwaksha',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 8, 21, 8, tzinfo=datetime.timezone.utc),
#   1652588885241655296,
#   '@Ashrafmbwana @Sirajitz1 Alafu Kuna miwatu wanasema wanalipaaaa 🤣',
#   'pasco_undole',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 30, 8, 13, 47, tzinfo=datetime.timezone.utc),
#   1652587033758511104,
#   '@mbuyuuu @Timra_raa Uaga mbayaa 😄 🤣',
#   'waweru2030',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 42, 56, tzinfo=datetime.timezone.utc),
#   1652579269791424513,
#   'Hammer shark giving advice on how to fish them out 😭😭😂🤣',
#   'GonaWaMwaksha',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 37, 5, tzinfo=datetime.timezone.utc),
#   1652577801008996352,
#   '@Mustbe_TJ @vidsthatgohard He he..alifikiwo 🤣 . They had posted a full movie 🍿',
#   'Namuks',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 34, 33, tzinfo=datetime.timezone.utc),
#   1652577164066160641,
#   '@hamzaalbhanj Ndio tuko 🤣 https://t.co/RgPsWAd0II',
#   'ZuwenaKhatib',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 23, 12, tzinfo=datetime.timezone.utc),
#   1652574304200949760,
#   '@Kamardine_M @NicolasRay03 Un avis le grand juriste 🤣 ? https://t.co/5v3QYfhE0G',
#   'jugeClarence',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 18, 30, tzinfo=datetime.timezone.utc),
#   1652573123621842947,
#   'Nze kati mbiraba ng’ebidomola 🤣',
#   'MeddieMambo',
#   6,
#   1],
#  [datetime.datetime(2023, 4, 30, 7, 11, 12, tzinfo=datetime.timezone.utc),
#   1652571284675411969,
#   '@YussufMwinyi @Nyasirwa 🤣',
#   'Every_TechTrend',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 7, 7, 18, tzinfo=datetime.timezone.utc),
#   1652570305548648448,
#   '@fredi999 Amazing 🤣😁😀',
#   'LazaroM58946814',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 49, 33, tzinfo=datetime.timezone.utc),
#   1652565836601737218,
#   '@SeraNjoro My fav too. Will be using it a lot now. Thanks 🤣',
#   'ANdaihera',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 47, 52, tzinfo=datetime.timezone.utc),
#   1652565413220212737,
#   '@itzjacton @Gaspinho15 Kama ni rahisi na nyie nendeni kwa mganga😂🤣',
#   'INFLUENCERjr',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 45, 58, tzinfo=datetime.timezone.utc),
#   1652564936831188992,
#   'wait for the right rich man 🤣….we’re coming 😂',
#   'plarisspaul',
#   3,
#   2],
#  [datetime.datetime(2023, 4, 30, 6, 42, 58, tzinfo=datetime.timezone.utc),
#   1652564181063745536,
#   '@Amazin_mf 🤣😂😂 izah',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 37, 5, tzinfo=datetime.timezone.utc),
#   1652562698834526214,
#   'I am a @ManUtd fan but KDB is better than Bruno. For testimony, you can ask @Arsenal 😂😂🤣',
#   'SsebuUg',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 24, 39, tzinfo=datetime.timezone.utc),
#   1652559572077355010,
#   "@KinusuIbrahim I'm not unwell. 🤣\nI'm 💉 the sick",
#   'thisis_jack',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 12, 55, tzinfo=datetime.timezone.utc),
#   1652556618628833280,
#   'Uko na akili au umepost hii ufala😂😂🤣 https://t.co/6t6V8mOxsy',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 6, 6, 51, tzinfo=datetime.timezone.utc),
#   1652555091625353216,
#   '@Mutuabrian_M 🤣😂😂',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 5, 56, 1, tzinfo=datetime.timezone.utc),
#   1652552364480507908,
#   '@Its_Roddie @Degrata254 🤣😂😂',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 5, 53, 18, tzinfo=datetime.timezone.utc),
#   1652551682197278720,
#   '@Wanji001 🤣😂',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 5, 44, 34, tzinfo=datetime.timezone.utc),
#   1652549485627682818,
#   '@rummy8191 Hamna 🤣',
#   'iAmLyimo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 5, 34, 56, tzinfo=datetime.timezone.utc),
#   1652547059549974529,
#   '@KabiruMurayah 🤣😂😂',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 5, 13, 14, tzinfo=datetime.timezone.utc),
#   1652541599501484035,
#   '@DorothNengai Ndiyoo 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 4, 59, 18, tzinfo=datetime.timezone.utc),
#   1652538093822517248,
#   '@EcEssie 🤣😂😂😂 eti they can attract tourists😥',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 30, 4, 40, 7, tzinfo=datetime.timezone.utc),
#   1652533264760832001,
#   "The same Europeans who helped him become President😂🤣\n\nThis guy hana chake...thinks he can be Sankara😂and yet he can't even deal with Nuru Okanga back home😂",
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 4, 20, 4, tzinfo=datetime.timezone.utc),
#   1652528219428462592,
#   '@currypistonn @Robertmathu 🤣',
#   'Namuks',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 30, 3, 18, 45, tzinfo=datetime.timezone.utc),
#   1652512789481619456,
#   '@Martinscdh Oyo wa primary five, anonye class ye zi full figure 🤣.',
#   'Omumerica2',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 22, 24, 56, tzinfo=datetime.timezone.utc),
#   1652438845676191755,
#   'You people, you have not understood what this goon is looking for from generational leader. He just simply needs his attention such that he can be called to meet him.\nTinkasiimire nawe ariyo naronda ka Rolex 🤣',
#   'EverestBushara',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 21, 4, 16, tzinfo=datetime.timezone.utc),
#   1652418547807576070,
#   '@iddynonga_ Ik wew jamaa😂🤣😂🤣',
#   'HerribertJ',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 21, 7, 12, tzinfo=datetime.timezone.utc),
#   1652419284772028417,
#   '🍊💊🚨\n#Bitcoin Vendors Meetup with one Vendor 🤣\n\nWell from the invite responses, we were expecting non! \nMost vendors are willing to learn about #Bitcoin but are so caught up serving their customers.\n\nWe overturned and targeted students last minute \U0001fae1 \nStill had New People 🤩 https://t.co/SGE9fMvjLp',
#   'BrindonMwiine',
#   105,
#   29],
#  [datetime.datetime(2023, 4, 29, 21, 36, 53, tzinfo=datetime.timezone.utc),
#   1652426752994443271,
#   '@cheekay_ @davidchibuike_ She was killed with a piece of her own dose 🤣😂🤣😂',
#   'JuukoAlex',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 37, 18, tzinfo=datetime.timezone.utc),
#   1652411758257270785,
#   '@IrakozeHosy Méfiez-vous aux apparences😅🤣 car  elles sont trompeuses🥱🥱 https://t.co/VW1ldsNVDC',
#   'irankundaken',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 32, 6, tzinfo=datetime.timezone.utc),
#   1652410451274153993,
#   '😂🤣😂✌️💯 https://t.co/lE7KXmnh0f',
#   'wa_stev',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 18, 32, tzinfo=datetime.timezone.utc),
#   1652407038339678209,
#   '@McinikaWaLamar #5 covers all 🤣',
#   'sangomussa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 15, 30, tzinfo=datetime.timezone.utc),
#   1652406274573623296,
#   '@ChelseaDiva10 Nisaidie gn mbili Mimi na @kalage_jr 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 8, 35, tzinfo=datetime.timezone.utc),
#   1652404534193553408,
#   '@only1banad @kevin_hunchoo Laba 🤣🤣🤣you never wish me any wins, do you??💀💀🤣',
#   'WeAreNtMatesBro',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 20, 2, 40, tzinfo=datetime.timezone.utc),
#   1652403042367537156,
#   '@LucasbrownTz Mkemia mkuuu😎🤣😂😆',
#   'SaidMdoe8',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 19, 56, 32, tzinfo=datetime.timezone.utc),
#   1652401501393031169,
#   '@Survivor_Uganda Orange I love that fruit 🤣',
#   'Davidkwilliam17',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 19, 16, 23, tzinfo=datetime.timezone.utc),
#   1652391395397599234,
#   '@EmmablesF @JuniorMazengo @Jungukuu3 @ayubu_madenge Wala hakuwauzia chumvi 🤣',
#   'khaledponera',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 19, 4, 49, tzinfo=datetime.timezone.utc),
#   1652388485666357255,
#   '@citizentvkenya 🤣😂🤣\n Whatever the piper plays, dance...',
#   'Twashelilly',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 18, 50, 16, tzinfo=datetime.timezone.utc),
#   1652384825473368064,
#   'The book is readable from its cover 😁😁😁😁😁😁😁😁😁😁😁😁😁🤣😁\n#ssot',
#   'AwangBoi',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 18, 46, 51, tzinfo=datetime.timezone.utc),
#   1652383965393698818,
#   'With zero shot on target😀😅🤣 https://t.co/UXE52IYp0j',
#   'atupele_benard',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 18, 44, 17, tzinfo=datetime.timezone.utc),
#   1652383318502174720,
#   '@NiiteTitan @theMadridZone Hazard afanye nini 🤣',
#   'richiethegemini',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 18, 43, 28, tzinfo=datetime.timezone.utc),
#   1652383113312387072,
#   "'Azolla imekaa Kama bangi ya mifugo'\nMdau Dm 🤣 https://t.co/bKsiYUzeAy",
#   'iAmLyimo',
#   46,
#   7],
#  [datetime.datetime(2023, 4, 29, 18, 40, 52, tzinfo=datetime.timezone.utc),
#   1652382459139325955,
#   'They have started to pick them up 😁🤣 https://t.co/6mQeiO8hDy',
#   'AMutwafu',
#   5,
#   1],
#  [datetime.datetime(2023, 4, 29, 18, 35, 4, tzinfo=datetime.timezone.utc),
#   1652380996778467328,
#   '@Adipojr51 @Y_vonne3 😂😂😂mnanimaliza😂😂🤣',
#   'fredLogedi',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 54, 45, tzinfo=datetime.timezone.utc),
#   1652370854464946179,
#   "The only problem with self love,is ... that you can't give yourself head😁🤣 https://t.co/tv0joYjpPb",
#   'AMutwafu',
#   9,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 54, 19, tzinfo=datetime.timezone.utc),
#   1652370742237904896,
#   "@MutagwanyaChar1 🤣😀😂me wasn't joking",
#   'JustineKenrose',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 51, 28, tzinfo=datetime.timezone.utc),
#   1652370026832248834,
#   '@CNairobian1_ 🤣',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 49, 32, tzinfo=datetime.timezone.utc),
#   1652369538933981187,
#   '@rajivga80767714 🤣',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 30, 3, tzinfo=datetime.timezone.utc),
#   1652364636623106052,
#   '@Mtu_Wa_Mjengoo 🤣😂😂',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 27, 35, tzinfo=datetime.timezone.utc),
#   1652364016864329728,
#   '@_7zack__ 🤣😂😂',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 7, 28, tzinfo=datetime.timezone.utc),
#   1652358953173504002,
#   '@luhya_kidd 😂😂🤣 niko hapa',
#   '_abelkirwa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 17, 3, 15, tzinfo=datetime.timezone.utc),
#   1652357890575933441,
#   '@NgowiGold Pampers za kitimoto za kutosha 🤣',
#   'davidludovick',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 55, 28, tzinfo=datetime.timezone.utc),
#   1652355934511824901,
#   '@Jim_maxy 😂😂😂😂🤣 leo niko na Safari',
#   'Samuel_nkingoJr',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 46, tzinfo=datetime.timezone.utc),
#   1652353550586896392,
#   '@evenmaina 😆 🤣 😂',
#   'p0tim',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 41, 2, tzinfo=datetime.timezone.utc),
#   1652352300206157825,
#   '@misterboldwood Guilty???🤣 huh!!',
#   'WeAreNtMatesBro',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 21, 29, tzinfo=datetime.timezone.utc),
#   1652347381101342720,
#   '@Yayuuuuu25 La virginité 🤣😅',
#   'irankundaken',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 18, 37, tzinfo=datetime.timezone.utc),
#   1652346661245517826,
#   '@BiryomumaishoB Sarah 🤣😂🤣 use a different phone 📱😂😂😂',
#   'EllyMemes_',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 16, 12, 40, tzinfo=datetime.timezone.utc),
#   1652345162994012162,
#   '@BunkzND 🤣 Buried six feet under. Not even a skilled archeologist can dig up his battered remains.',
#   'BenonGowa',
#   2,
#   1],
#  [datetime.datetime(2023, 4, 29, 16, 10, 47, tzinfo=datetime.timezone.utc),
#   1652344686843920386,
#   '@Kiganyi_ 😄😄😄😄🤣',
#   'TabasamuTz',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 15, 49, 25, tzinfo=datetime.timezone.utc),
#   1652339310501281793,
#   '@nyondothegun0 @MalemboLE @MalemboFarm @MalemboIntern 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 15, 14, 57, tzinfo=datetime.timezone.utc),
#   1652330639608168449,
#   '@IssangyaJ @ndembo255 Sas professional ya mtu inahusiana vp na hz banters za kimpira tuh kak😀😀😀mbona sukari imekupand san ivo mzeee🙌🏻😂🤣',
#   'HerribertJ',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 15, 8, 25, tzinfo=datetime.timezone.utc),
#   1652328995042607105,
#   '@Owishemwe Gitere nshwere 🤣',
#   '_Ngabirano',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 14, 57, 47, tzinfo=datetime.timezone.utc),
#   1652326316216139777,
#   '@yua_maganjiplug 🤣 🤣 🤣',
#   'KhachulaBildard',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 14, 5, 2, tzinfo=datetime.timezone.utc),
#   1652313041671798784,
#   'So might have to model on a runway in swimwear next month 🤣 does this mean I should start gyming!? \U0001fae0',
#   '_Christie98',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 13, 53, 8, tzinfo=datetime.timezone.utc),
#   1652310048159289344,
#   "Hutu tu 5'2 unacheza na yeye kama ball kwa bed😂🤣",
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 13, 41, 8, tzinfo=datetime.timezone.utc),
#   1652307026033229825,
#   "@Hildabae8 That's being rude tho 🤣",
#   'ChrismasMKhan',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 13, 38, 15, tzinfo=datetime.timezone.utc),
#   1652306303388200960,
#   "@RakanRabih @Tiago_cvs 😂😂talk about the 2 UCL trophies😂not the 7 finals they reached and lost \nYou're just emphasising how out of 9 finals they lost 7😂🤣",
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 13, 0, 38, tzinfo=datetime.timezone.utc),
#   1652296834512048130,
#   '@malkia_kenya 🤣😂😂 jehovah😂😂😂',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 12, 49, 45, tzinfo=datetime.timezone.utc),
#   1652294098542288898,
#   '@Miss_Prresident The rock 🤣',
#   'HoskipT',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 12, 30, 43, tzinfo=datetime.timezone.utc),
#   1652289308177383424,
#   '@AnethStanley @privaldinho Wew mwenye akil uliend South ukachoma uwanja wa watu na bdo ukakandwa🚮😂🤣😂🤣😂🤣🤲🏻',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 12, 17, 15, tzinfo=datetime.timezone.utc),
#   1652285918613471232,
#   '@Papasg8 @NatieNampa @mckin_love @julian_arinda Nothing 🤣😂😂😂😂😂😂😂',
#   'octoberbae914',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 12, 14, 45, tzinfo=datetime.timezone.utc),
#   1652285290466140160,
#   'Ukona sexy eyes ama Bora uone mbele 😂💔🤣😂 https://t.co/EGf5MAzETl',
#   'DennisM70784253',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 12, 13, 49, tzinfo=datetime.timezone.utc),
#   1652285055740547072,
#   '@DeejayKalz Oxygen pro max 🤣',
#   'Davidkwilliam17',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 53, 5, tzinfo=datetime.timezone.utc),
#   1652279834905571329,
#   '🤣',
#   'BenonGowa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 49, 24, tzinfo=datetime.timezone.utc),
#   1652278909944184832,
#   '@vinasetto 😅😅🤣',
#   'Alexmaingi17',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 40, 33, tzinfo=datetime.timezone.utc),
#   1652276683947294721,
#   '@AdikaChristine Pastor Ezekiel 🤣',
#   'Philsmosoti',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 40, 12, tzinfo=datetime.timezone.utc),
#   1652276594780647428,
#   '@ahmed__ally Unahis nyie ndo team ya kwanz kucheza na waarabu ugenin sas😂😂😂halaf mnategemea kbsaa mshinde ety😂🤣😂🤣waulizen wale WaTunisia bhn',
#   'HerribertJ',
#   6,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 18, 34, tzinfo=datetime.timezone.utc),
#   1652271150758604802,
#   '@R0j3rkon4t @_anne_254_ 😂🤣💀',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 13, 18, tzinfo=datetime.timezone.utc),
#   1652269826293760000,
#   '@nyaayoJr @cnw9001 Oya💀🤣',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 11, 0, 40, tzinfo=datetime.timezone.utc),
#   1652266646449397766,
#   "Don't allow all people more successful than you to make you feel like it's so just because you aren't as hardworking 😝🤣 https://t.co/UZE13Xfet0",
#   'Uganda_Expozed',
#   10,
#   2],
#  [datetime.datetime(2023, 4, 29, 10, 38, 50, tzinfo=datetime.timezone.utc),
#   1652261150183006208,
#   '@_rowie__ Bbanaye 🤣',
#   'nikitalynjrrl_',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 10, 2, 48, tzinfo=datetime.timezone.utc),
#   1652252083326709761,
#   '@ZeeroBrain It’s a report with high images and artwork. 🤣',
#   'Spartakussug',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 10, 0, 22, tzinfo=datetime.timezone.utc),
#   1652251471193206784,
#   '@quaggmaya @KenyaAirways Brazilian probox.... 🤣',
#   'zuberiom',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 9, 53, 56, tzinfo=datetime.timezone.utc),
#   1652249851512471553,
#   'Sasa arsenal kiherehere ilikua ya nini majamaa 🤣 😂',
#   'DominicKatamo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 9, 45, 43, tzinfo=datetime.timezone.utc),
#   1652247784857260033,
#   'You ain’t getting that even. 🤣',
#   'LuckyAgabaa',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 9, 44, 1, tzinfo=datetime.timezone.utc),
#   1652247354928398336,
#   'Guys how do I approach my crush 🤣😂🤣😂',
#   'moneyhunter443',
#   6,
#   3],
#  [datetime.datetime(2023, 4, 29, 9, 42, 11, tzinfo=datetime.timezone.utc),
#   1652246893932564483,
#   'i love when men ask me what my type is and i start describing the opposite of how they look like🤣🤣 i’d tell a 6’1 nigga i love my men short just like me😭🤣 or tell a dark skinned man how im really obsessed with lightskins😭🤣 it gives me some sort of weird satisfaction 🤣🤣',
#   'srugzz',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 59, 21, tzinfo=datetime.timezone.utc),
#   1652236113250058240,
#   'Eti ooh “hatuwadia” mliwakopesha kitu gani? 😄🤣',
#   'KingNaeemz',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 56, 23, tzinfo=datetime.timezone.utc),
#   1652235367175581696,
#   'Nyoka tena😂🤣',
#   'terry_kagure',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 50, 51, tzinfo=datetime.timezone.utc),
#   1652233974570180609,
#   '@mrembointown @swamukonya 🤣 we blame the previous regimes for not teaching us',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 44, 12, tzinfo=datetime.timezone.utc),
#   1652232300472541186,
#   'All ministries in Kenya are run by a kalenjin PS somewhere😂🤣',
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 43, 5, tzinfo=datetime.timezone.utc),
#   1652232020867661824,
#   'Anti-Suceur @nekatramboyiihi c’est le plus gros retournement du tweetgame mahorais 🤣',
#   'marine_976',
#   11,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 35, 1, tzinfo=datetime.timezone.utc),
#   1652229991424196610,
#   '@MouSaliim Kweli 🤣',
#   'iAmLyimo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 22, 11, tzinfo=datetime.timezone.utc),
#   1652226761378209794,
#   'Arsenal top 3😂😂🤣😭😭BOTTLERS FC😂',
#   'MrCold37',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 3, 52, tzinfo=datetime.timezone.utc),
#   1652222153377435649,
#   '@HonMoses_Kuria Tebu sema the word uderwerming waziri😂😂🤣',
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 8, 0, 45, tzinfo=datetime.timezone.utc),
#   1652221366874042369,
#   '@EmceeKiira @Esau_Matsiko @CanaanArinda @chubbyaudrey22 @lawrencekitema @AshrafMarvelArt @OfficialSwaib @kingFahad_17 Hold it properly u may lose it even next season 🛌🛌🛌🛌💁😂😂🤣👇👇 https://t.co/WLjvcMI7qJ',
#   'YusufMusaUG1',
#   1,
#   1],
#  [datetime.datetime(2023, 4, 29, 7, 58, 4, tzinfo=datetime.timezone.utc),
#   1652220693558308865,
#   '@Malkia__ Wakili basi 🤣',
#   'LauraKaindi',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 7, 48, 32, tzinfo=datetime.timezone.utc),
#   1652218295301357568,
#   "Doesn't Arteta have football depth😂🤣\nOf all CDMs in Europe?\n\nKante?c'mon",
#   'MrCold37',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 7, 47, tzinfo=datetime.timezone.utc),
#   1652217907588259840,
#   'Jaguar really sang this as a msanii years before becoming a politician…\n\nmwanasiasa aliniomba kura\nakiniahidi yote atatimiza\nbaada ya miaka tano anarudi na kitambi\nbila kutimiza\n\nThen went ahead and campaigned and became an MP and did exactly as he had sang it. Ridiculous 🤣',
#   'Keeplah',
#   22,
#   10],
#  [datetime.datetime(2023, 4, 29, 7, 40, 29, tzinfo=datetime.timezone.utc),
#   1652216267514822657,
#   '@PresKyallo @ValNgugi 🤣',
#   'LauraKaindi',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 7, 33, 33, tzinfo=datetime.timezone.utc),
#   1652214523116306434,
#   '@AngellaMumbejja @MercyMelody9 Yeah, for the Spiritual Perspective, they were the fountain but other things like physical perspective nara 🤣😁',
#   'kingRMZ_256',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 7, 11, 2, tzinfo=datetime.timezone.utc),
#   1652208854518702081,
#   '@kipepe123 Katafute kazi si una degree wewe?🤣',
#   'INFLUENCERjr',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 6, 47, 4, tzinfo=datetime.timezone.utc),
#   1652202825953288193,
#   '@Bernice_Karanja Aki.....Life requires patience, wisdom and discipline enter-twinned together... Bila wisdom mtu anakuwa brainwashed.....🤣',
#   'LogMary_Nuggets',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 6, 34, 22, tzinfo=datetime.timezone.utc),
#   1652199630178754560,
#   '@Marge_DTM Kifo hakinaga ujinsia! 🤣',
#   'sangomussa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 6, 31, 34, tzinfo=datetime.timezone.utc),
#   1652198924419997699,
#   '@TheKingHersel13 Nedda 🤣',
#   'Sunshinerwa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 6, 12, 50, tzinfo=datetime.timezone.utc),
#   1652194210886418434,
#   "@RealDjLennon1 Can't believe that this is happening 🤣😂",
#   'Josephensburg23',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 44, 33, tzinfo=datetime.timezone.utc),
#   1652187090786852866,
#   '🤣 Is actually Vaseline',
#   'msritha29',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 42, 40, tzinfo=datetime.timezone.utc),
#   1652186617480716288,
#   '@Marge_DTM Parenting bila ubabe utoboi 🤣',
#   'sangomussa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 34, 6, tzinfo=datetime.timezone.utc),
#   1652184460782194688,
#   '@HBumbuli Kifo hakina ujinsia kaka 🤣',
#   'sangomussa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 24, 56, tzinfo=datetime.timezone.utc),
#   1652182154221088769,
#   '🤣',
#   'macelikes',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 16, 28, tzinfo=datetime.timezone.utc),
#   1652180024231960577,
#   '@BirdyMan__ Compte creer en Avril 🤣 «\xa0Mayotte repond\xa0» jvai taper des barres',
#   'monsieurrdisney',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 5, 4, 20, tzinfo=datetime.timezone.utc),
#   1652176972498231296,
#   '@PaschalSam1 Hatuhusiki na watachokutana nacho, kazi yetu wamemaliza Jana 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 29, 4, 45, 7, tzinfo=datetime.timezone.utc),
#   1652172134301548545,
#   "It's like we're going to need a Salmon vs Salmon of sorts. How does one draw a clear dichotomy of a personal handle and a Ministry Twitter handle 🤣. This Labisa thing and it's twin sister, Exhibition will rattle heads most certainly 🤣🤣🤣",
#   'enenslink',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 4, 27, 44, tzinfo=datetime.timezone.utc),
#   1652167759839502337,
#   '@omaakatugba Lol 🤣😂',
#   'AdevieDerima',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 4, 16, 40, tzinfo=datetime.timezone.utc),
#   1652164975492726791,
#   '@_vmsutze @ShabanSalehe Brighter Future 🤣',
#   'gcngo88',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 4, 11, 9, tzinfo=datetime.timezone.utc),
#   1652163587358466049,
#   '@Ghetto_kd 😆 🤣',
#   'p0tim',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 3, 52, 22, tzinfo=datetime.timezone.utc),
#   1652158861451710464,
#   '@LegalEzra As always 🤣',
#   'LauraKaindi',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 3, 39, 49, tzinfo=datetime.timezone.utc),
#   1652155702830325760,
#   '@admyral47 🤣',
#   'TMswahili',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 2, 50, 59, tzinfo=datetime.timezone.utc),
#   1652143411221110785,
#   'Not going to church and doing long run 🤣',
#   'Warighej',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 29, 0, 37, 41, tzinfo=datetime.timezone.utc),
#   1652109868168359936,
#   '@jemedarisaid 🤣😅😅wanapambana pasipo shot on target',
#   'atupele_benard',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 23, 3, 22, tzinfo=datetime.timezone.utc),
#   1652086131725414402,
#   '@GIVENALITY Mbon ulitolewa na Orlando huko huko kweny kona baad ya kuchom mpk uwanj😂🤣',
#   'HerribertJ',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 28, 22, 41, 38, tzinfo=datetime.timezone.utc),
#   1652080660419342338,
#   '@CharlieBihemo Hasira za nn wew kolo🚮😂🤣',
#   'HerribertJ',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 28, 22, 38, 35, tzinfo=datetime.timezone.utc),
#   1652079892421308418,
#   '@zittokabwe You did well na mmetoka😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 22, 36, 57, tzinfo=datetime.timezone.utc),
#   1652079484063956992,
#   '@zittokabwe @SimbaSCTanzania Ety team ya taifa daaah🚮😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 22, 34, 41, tzinfo=datetime.timezone.utc),
#   1652078910455050240,
#   '@batuli_actress Bingwa wa kuishia robo final😂🤣😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 55, 47, tzinfo=datetime.timezone.utc),
#   1652069123646541824,
#   '@mzeewakaliua 🙌🙌🙌😀🤣😅',
#   'atupele_benard',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 42, 24, tzinfo=datetime.timezone.utc),
#   1652065753024147458,
#   '@AziziEsq 🤣',
#   'ItsMgwamiJnr',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 42, 7, tzinfo=datetime.timezone.utc),
#   1652065681410539520,
#   '@PresenterNoah Best CAM ever kweny ligi kuu bara🚮😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 37, 34, tzinfo=datetime.timezone.utc),
#   1652064538454290433,
#   '🤣👋🤣 https://t.co/skNzNiY14x',
#   'shija75755522',
#   1,
#   1],
#  [datetime.datetime(2023, 4, 28, 21, 35, 34, tzinfo=datetime.timezone.utc),
#   1652064033250353153,
#   '@_fels1 Watu watahepa na bills 🤣',
#   'livin_omanga',
#   8,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 33, 36, tzinfo=datetime.timezone.utc),
#   1652063538486050818,
#   '@Semkae @zittokabwe Mtani nina jamaa anaitwa Martha Kalipeni 🤣 sounds like hilo neno lako la mwisho 🤣🤣🤣',
#   'ntmomega',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 29, 59, tzinfo=datetime.timezone.utc),
#   1652062628645052417,
#   '"Shangilia ila usiniguse"🤣 https://t.co/E8BoPaLMtR',
#   'CosmasJN',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 19, 33, tzinfo=datetime.timezone.utc),
#   1652060002763276290,
#   '@SimbaSCTanzania Weuuuuweee 😂😂🤣 https://t.co/C20w0W549O',
#   'deo_tesha007',
#   33,
#   12],
#  [datetime.datetime(2023, 4, 28, 21, 18, 47, tzinfo=datetime.timezone.utc),
#   1652059812341874689,
#   "@NjeriBt @LamechNyakoe See the reason. Can't be associated with such mediocre characters 🤣",
#   'livin_omanga',
#   7,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 15, 56, tzinfo=datetime.timezone.utc),
#   1652059095065587713,
#   '@muharawaSeguya @humble_guy01 @ArthurMuhwezi12 @DesiignerCroose Squats zayanga shi?🤣',
#   'AndyMKing1',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 11, 30, tzinfo=datetime.timezone.utc),
#   1652057977539506177,
#   '@PKishamba Vp msimamo wako bdo umeushikilia tuh au😂🤣😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 9, 54, tzinfo=datetime.timezone.utc),
#   1652057573896474626,
#   '🤣😂🤣😂🤣',
#   'IrumbaO',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 21, 9, 18, tzinfo=datetime.timezone.utc),
#   1652057424625319937,
#   '@lunbeato @NjeriBt 🤣',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 51, 50, tzinfo=datetime.timezone.utc),
#   1652053027820281862,
#   '@Allycaydo1 Key Point: you think 🤣',
#   'RichRadick',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 47, 38, tzinfo=datetime.timezone.utc),
#   1652051972764123136,
#   '@JotiOfficial 🤣🙆🏿\u200d♂️',
#   'NkwabiDonald',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 20, 42, tzinfo=datetime.timezone.utc),
#   1652045195326660622,
#   '@Ammar_Kassim8 Maybe ame fast 😅😂🤣',
#   'StephenWakarera',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 16, 57, tzinfo=datetime.timezone.utc),
#   1652044249624354849,
#   '@NytoTony @Nyokaffiii 🤣',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 13, 3, tzinfo=datetime.timezone.utc),
#   1652043269507891201,
#   '@Mr_Faddy1 @yonga_arts 🤣',
#   'MMwakulomba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 11, 11, tzinfo=datetime.timezone.utc),
#   1652042797694713856,
#   'How High film 😂 on @GOtvUganda  #MovieRoom 🤣',
#   'ChefKarim02',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 20, 7, 42, tzinfo=datetime.timezone.utc),
#   1652041922133762076,
#   "This lad just said I'm the best dancer in the world 🤣🤣🤣🤣🤣🙌...I love how easily impressed these people are 🤣💀🤭🤭🤭 https://t.co/HjwtKbkkAp",
#   'CallMeM254',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 28, 19, 56, 21, tzinfo=datetime.timezone.utc),
#   1652039065586245639,
#   'Jamaaa huyu bhnaaa mhh 🤣😂😂 https://t.co/Bj5XX9TY7m',
#   'AyoubMwaisa',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 28, 19, 52, 5, tzinfo=datetime.timezone.utc),
#   1652037992641380353,
# ...
#   1650222807828123662,
#   'Weghorst 😆 🤣',
#   'p0tim',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 36, 54, tzinfo=datetime.timezone.utc),
#   1650222233313239043,
#   'Ok, can someone stop this nonsense 🤣',
#   '_mudhor',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 32, 20, tzinfo=datetime.timezone.utc),
#   1650221083113431044,
#   '@Mo_utdred Wtf, hw cld you aloow AWB to pocket you like that. Nio. 🤣 https://t.co/7e4XxfjvZM',
#   'mr_opaba',
#   9,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 29, 48, tzinfo=datetime.timezone.utc),
#   1650220445256302594,
#   'Halafu msijisahaulishe, Rivers United wametuchezesha saa nane mchana (02:00pm) ambayo kwa huku kwetu ni saa kumi (04:00pm).\n\nNawaona tu mnavyo jizima data na Vichaambuzi vyenu uchwara 😁🤣',
#   'LiamTewodros',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 23, 38, tzinfo=datetime.timezone.utc),
#   1650218892558581760,
#   '@brfootball United is cooking. 🤣 https://t.co/b5g9QHRffv',
#   'mr_opaba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 22, 50, tzinfo=datetime.timezone.utc),
#   1650218691055742987,
#   '😂😂Nicholas the dark munyankole to use snap chat 😂🤣 https://t.co/0HuXN9ofeU',
#   'MichealNasasira',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 22, 12, tzinfo=datetime.timezone.utc),
#   1650218534553673729,
#   '@hssnkirevu @cherryyarns Wabula you two🙌🙌🤣🤣🤣 kati bino biki💀🤣',
#   'WeAreNtMatesBro',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 21, 39, tzinfo=datetime.timezone.utc),
#   1650218395109924865,
#   '@AllanSseky What makes you think getting a right one was plan A in the first place 🤣 https://t.co/lcneyufQQY',
#   'A_One_Prince',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 20, 10, tzinfo=datetime.timezone.utc),
#   1650218022882140163,
#   '@MLDataKe 🤣💔is it that bad ?',
#   'Romans_Paul49',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 20, 2, tzinfo=datetime.timezone.utc),
#   1650217987754917890,
#   '@CharityKarungi_ HYesus🤣😭🤣😭 https://t.co/KDJKvnycIv',
#   'TheboyfromToro',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 18, 21, tzinfo=datetime.timezone.utc),
#   1650217564721627137,
#   "@BennonMaina @BBCNews @metpoliceuk @LondonFire Ok. That's good actually. For a min I thought well you know what 😅👀🤣. My apologies for doubting.",
#   'ANdaihera',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 5, 38, tzinfo=datetime.timezone.utc),
#   1650214361988726784,
#   '@arthur_kizige @ManUtd Man, we should take the city players to pens, that way we have a chance 🤣',
#   'zlatan_emma',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 19, 4, 44, tzinfo=datetime.timezone.utc),
#   1650214137715195905,
#   'And it will be trouble in united side 🤣',
#   'IbRaH_ShEbY',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 57, 44, tzinfo=datetime.timezone.utc),
#   1650212376661176321,
#   '@centredevils We cooked. This was for eliminating Arsenal from Carabao Cup. 🤣 CC. @Arsenal 🤝 https://t.co/gI8OvCrO5W',
#   'mr_opaba',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 56, 34, tzinfo=datetime.timezone.utc),
#   1650212080077660160,
#   'Hii age angu, hairuhusu kusuffer for love, so if you see me sad, ni sababu sina Pesa tu😒🤣',
#   'msritha29',
#   4,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 56, 27, tzinfo=datetime.timezone.utc),
#   1650212052936400897,
#   "@_ReneOG We're playing UCL semis against real Madrid man, Chill 🤣",
#   'davidn250',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 55, 38, tzinfo=datetime.timezone.utc),
#   1650211845918040070,
#   '@rashel_256 🤣 Manchester United style 😂😂😂',
#   'klausepoch',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 51, 16, tzinfo=datetime.timezone.utc),
#   1650210746972663810,
#   'Nilivoona wameenda matuta nikamwambia mshkaji wangu atakayepaisha kaamua mechi, \nMagolikipa wote unga sana kwenye matuta 🤣',
#   'rayasel94',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 42, 14, tzinfo=datetime.timezone.utc),
#   1650208476629540866,
#   'Hakuna vile March anaeza funga April. 🤣',
#   'Merddie',
#   11,
#   3],
#  [datetime.datetime(2023, 4, 23, 18, 32, 58, tzinfo=datetime.timezone.utc),
#   1650206143057211393,
#   "@Amata_Yokeje Hhhh with that leg looks like Jack Grealish's?🤣",
#   'davidn250',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 32, 1, tzinfo=datetime.timezone.utc),
#   1650205901876256775,
#   'This pothole will switch your data from @LycamobileUG to @Airtel_Ug 😀🤣✍️\U0001faf4 https://t.co/5u1vDEkFoc',
#   'Raezartshub',
#   8,
#   1],
#  [datetime.datetime(2023, 4, 23, 18, 24, 56, tzinfo=datetime.timezone.utc),
#   1650204122497384449,
#   '@emamhimbira @itshappie Baggy not babby vip mzee?🤣',
#   'Muuza_mashati',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 21, 59, tzinfo=datetime.timezone.utc),
#   1650203378104803328,
#   "@Capiii_ Can't believe with all that mwaks he can't even save one 🤣 but at least he unsettled March.",
#   'ahmedayyo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 17, 30, tzinfo=datetime.timezone.utc),
#   1650202249220456450,
#   'Imagine the way how United is struggling 🤣',
#   'DarionAmpaire',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 14, 34, tzinfo=datetime.timezone.utc),
#   1650201514072219652,
#   '@MISSCHINDIYA Thats too much pressure Kimes eish 😩😢🤣',
#   'NyashaKMutizwa',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 18, 7, 42, tzinfo=datetime.timezone.utc),
#   1650199784337072131,
#   'For this trip I was simply going with the flow, zero planning , no itinerary just vibes &amp; in shaa Allah. Had to catch the 0930Hrs ferry for my 1550Hrs departure. was in a 4 sleeper cabin - 1st class with the “estimated” travel time being approx 46 hrs 😭🤣😂 https://t.co/h16txUJZnx',
#   'Farahdeez',
#   16,
#   1],
#  [datetime.datetime(2023, 4, 23, 17, 57, 32, tzinfo=datetime.timezone.utc),
#   1650197226147270659,
#   '@KeishaBrilliant Nga you know how to investigate sis 😂😂😂🤣',
#   'AnkwatseRitah',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 57, 16, tzinfo=datetime.timezone.utc),
#   1650197160279908356,
#   'Ohoooo 🤣',
#   'HusseinChando',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 52, 2, tzinfo=datetime.timezone.utc),
#   1650195842161168384,
#   '🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣😁🤣🤣😁😁🤣😄🤣',
#   'kilepi_tweve',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 47, 39, tzinfo=datetime.timezone.utc),
#   1650194737662500865,
#   '@SpireJim @OpoyaFrancis Yongera ku volume philosopher 🤣',
#   'Aloysiuskayita',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 47, 23, tzinfo=datetime.timezone.utc),
#   1650194672608763907,
#   'I used to study using lightening...\nSince we are dumb @dpgachagua\n@citizentvkenya \n🤔🤔😂🤣😂🤣 https://t.co/bzFnAc0xKw',
#   'rohankato1',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 29, 55, tzinfo=datetime.timezone.utc),
#   1650190276537843713,
#   'The elephant trumpet took me out!! 🤣',
#   'Mwanikih',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 25, 33, tzinfo=datetime.timezone.utc),
#   1650189178712342528,
#   '@WaruiJohn2 😂😂🤣 black magic https://t.co/Oc8xcmkHbC',
#   'UzimaComrade',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 24, 10, tzinfo=datetime.timezone.utc),
#   1650188826864676865,
#   'Kuna mtu hajui Kesho anavaa Nini? 🤣\n.\nHizi hapa kadeti: Bei: 25,000/=\n.\nSize: 32-40\n.\nNjoo Whatsapp Chap nifanye delivery 🛒👇\n.\nhttps://t.co/oJYPCt1EEC\n.\nMkoani unapokea ndani ya 24 hrs 🛒\n.\nNisaidie ku Retweet 💪🛍️\n.\n#NipeDili #Sokoletu https://t.co/XstOYomndQ',
#   'Dream_onlineshp',
#   9,
#   5],
#  [datetime.datetime(2023, 4, 23, 17, 23, 51, tzinfo=datetime.timezone.utc),
#   1650188747571339265,
#   'One day it will come to an end when your 40days are done 😂🤣\n\n#NRGVines #NRGRadioUG https://t.co/vgd5YmRXjH',
#   'NRGRadioUganda',
#   13,
#   4],
#  [datetime.datetime(2023, 4, 23, 17, 19, 37, tzinfo=datetime.timezone.utc),
#   1650187682696265728,
#   '@Chebon_Esq 🤣😂😂',
#   'UzimaComrade',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 17, 33, tzinfo=datetime.timezone.utc),
#   1650187161877069825,
#   '@CAFCLCC Scored against average club 🤣🚮',
#   'NgopeFelix',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 12, 21, tzinfo=datetime.timezone.utc),
#   1650185856756461570,
#   '@OliveOlovely @BunkzND No wahala... rugby is a beautiful game 🤣 https://t.co/WbQw8fMSzj',
#   'Benjie_BDO',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 9, 5, tzinfo=datetime.timezone.utc),
#   1650185034375077889,
#   'My attitude this week 🤣',
#   'AnitaKomukama',
#   5,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 7, 52, tzinfo=datetime.timezone.utc),
#   1650184726907351041,
#   '@KhanDuncan1 Hahaha 🤣',
#   'thee_wordscribe',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 17, 0, 6, tzinfo=datetime.timezone.utc),
#   1650182772273627137,
#   '@BradleyCarl256 @osward_cartoons remember this?🤣',
#   'GingoSamuel',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 55, 11, tzinfo=datetime.timezone.utc),
#   1650181535809642496,
#   '@barcitybaby Taarifa zako nnazo 😅😂🤣',
#   'Y_carter',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 52, 48, tzinfo=datetime.timezone.utc),
#   1650180934317101057,
#   '🤣😂💯 perfectly balanced as all things should be',
#   'Y_carter',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 51, 32, tzinfo=datetime.timezone.utc),
#   1650180617407963136,
#   '@unclemahad @SpireJim Okitegeera?? 🤣💦',
#   'Ebonyeyes10',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 51, 29, tzinfo=datetime.timezone.utc),
#   1650180604959367174,
#   '@mizschels We need hands 🤣 https://t.co/8Pwqvx7bvv',
#   'Able_mee',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 49, 36, tzinfo=datetime.timezone.utc),
#   1650180130331930624,
#   "😂😂🤣 He's joblessly rotting in Bondo,Kipye!!!Give him something before he resumes in the usual job  eating teargas 😂😂",
#   'nickiwisky',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 42, 29, tzinfo=datetime.timezone.utc),
#   1650178340756549637,
#   "Who stopped maandamano 😂🤣 and if that's not enough for you,you can continue with your maandamano at night hour when we are just asleep 😂🤣🤣!??",
#   'nickiwisky',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 39, 28, tzinfo=datetime.timezone.utc),
#   1650177578416631808,
#   '@realest_drizzy 🤣😂💀',
#   'UzimaComrade',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 39, 9, tzinfo=datetime.timezone.utc),
#   1650177501509951490,
#   '😂😂🤣 No case to answer advocate after burying 21 persons in his farm 😂🤣🤣!!!Kweli,which witchcrafty is real!!?',
#   'nickiwisky',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 38, 37, tzinfo=datetime.timezone.utc),
#   1650177365186691073,
#   'Trust me,uchawi upo😅😀🤣',
#   'atupele_benard',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 34, 5, tzinfo=datetime.timezone.utc),
#   1650176223182454791,
#   '😂Bambi these sculptures of celebrities are in Madame Tussaud’s wax museum, New York. Akaana kaleke kato nnyo 🤣',
#   'MeddieMambo',
#   3,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 29, 43, tzinfo=datetime.timezone.utc),
#   1650175126732697603,
#   "Give us. notes new about your maandamano 😂😂🤣 as Islamic holidays is behind us!!!Stop telling about others people's wife's as yours seems to be problematic!!!",
#   'nickiwisky',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 27, 40, tzinfo=datetime.timezone.utc),
#   1650174609335959558,
#   '🤣',
#   'NichekiHewani',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 26, 47, tzinfo=datetime.timezone.utc),
#   1650174389491585028,
#   '@mr___honey Kikiki 😆 🤣',
#   'p0tim',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 20, 51, tzinfo=datetime.timezone.utc),
#   1650172893647581184,
#   '🤣 🤣 🤣',
#   'Lovingson_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 17, 51, tzinfo=datetime.timezone.utc),
#   1650172137846587397,
#   '@Adventure_36 🤣',
#   'iAmLyimo',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 16, 9, 5, tzinfo=datetime.timezone.utc),
#   1650169934008262658,
#   '@SammyGikonyo @wambuisophie @DrLoupis @TuJadili @MissMihari @anj_116_ @theNjiiris @rcnjuguna @pkangata @gitaujosephbm @MichaelKonye3 🤣 🤣 🤣',
#   'Mwangimyke',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 15, 32, 14, tzinfo=datetime.timezone.utc),
#   1650160658560811013,
#   "Let's goooo..🤣",
#   '1_mayanja',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 15, 28, 8, tzinfo=datetime.timezone.utc),
#   1650159628057976836,
#   '@DaanDeWit Geef aan aan waar dat in de Great Reser staat 🤣 totaal niets begrepen van wat het WEF wil duiden, te dom voor (heb je het ooit gelezen?) WEF is kleiner dan stadsbestuur Amsterdam en zou de hele wereld beheersen 🤣 sukkel',
#   'ruudvz',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 15, 14, 43, tzinfo=datetime.timezone.utc),
#   1650156251882442754,
#   '@elonmusk \U0001fae3\U0001fae1😁🤣',
#   'lawrencelotkok',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 36, 24, tzinfo=datetime.timezone.utc),
#   1650146609059987459,
#   '@MarekaMalili Halaf unakuta analonganishwa na Othos😂🤣',
#   'HerribertJ',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 20, 8, tzinfo=datetime.timezone.utc),
#   1650142513439670273,
#   '@0mega001 @fynRuthie Cask lounge 🤣',
#   'Andrey256_',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 16, 33, tzinfo=datetime.timezone.utc),
#   1650141612465422336,
#   '@kika_susan Bado uko na kampeni ya kutupanga. 🤣 https://t.co/obAG1JjsVj',
#   'davidsalvatory_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 14, 5, tzinfo=datetime.timezone.utc),
#   1650140994271076352,
#   '@boris001234 Atleast she doesnt have those eyes 🤣',
#   'ellypetero',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 14, 5, tzinfo=datetime.timezone.utc),
#   1650140993008685062,
#   'Hey @qataharraymond, it seems the coffee mafia was documented making illicit substances in the back of the party. 🤣\n\nSmart of that mzungu to use a hat to hide her identity. https://t.co/Pdgx6O9Km4',
#   'mbjorgum',
#   29,
#   3],
#  [datetime.datetime(2023, 4, 23, 14, 7, 31, tzinfo=datetime.timezone.utc),
#   1650139342285729792,
#   '@AtypicalWes 🤣💀I’ll change my handle',
#   'Exildah_N',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 14, 0, 43, tzinfo=datetime.timezone.utc),
#   1650137629235486722,
#   '@keithnamu The other gender 😂🤣',
#   'Dkphaneroo',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 57, 33, tzinfo=datetime.timezone.utc),
#   1650136831990673410,
#   '@M3ervyn @jayteemuro Use your imagination 🤣',
#   'NyagahJoyy',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 56, 40, tzinfo=datetime.timezone.utc),
#   1650136608450961416,
#   'Loving it black and white, happy sunday 🤣 https://t.co/rfZq9F80X9',
#   'Andrey256_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 52, 32, tzinfo=datetime.timezone.utc),
#   1650135569421279234,
#   "@risingsunSW6 I didn't expect this 🤣",
#   'davidsalvatory_',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 32, 58, tzinfo=datetime.timezone.utc),
#   1650130647531307009,
#   '🤣',
#   'ThisIsEndweza',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 29, 24, tzinfo=datetime.timezone.utc),
#   1650129747496558592,
#   '@Ondigibush1 Una shares 🤣',
#   'jrmitoko',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 21, 50, tzinfo=datetime.timezone.utc),
#   1650127844419436544,
#   '20 minutes and 5 goal for Newcastle 🤣',
#   'NMulindwa',
#   2,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 21, 21, tzinfo=datetime.timezone.utc),
#   1650127720204959746,
#   '@AndieKeysh @Osama_otero This is epic guys 🤣💪🏾',
#   'pmmburu',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 20, 34, tzinfo=datetime.timezone.utc),
#   1650127525476016128,
#   '@_ReneOG Ubundi se murimo?🤣 3:0',
#   'davidn250',
#   1,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 13, 16, tzinfo=datetime.timezone.utc),
#   1650125687875878915,
#   'Y’all apologize when you sneeze but don’t when you’re  wrong.🤣',
#   'MsNshimbi',
#   7,
#   1],
#  [datetime.datetime(2023, 4, 23, 13, 12, 49, tzinfo=datetime.timezone.utc),
#   1650125574591987715,
#   '@madamloyal @MarekaMalili 😂🤣 https://t.co/r1HU9dqhgA',
#   'HerribertJ',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 11, 16, tzinfo=datetime.timezone.utc),
#   1650125183015874561,
#   '@deheij @Nkruif @telegraaf In Nederland, in Afrika kan geen boer concurrentie met de NL kippen belasting wordt ontweken via Zuidas, Kilimanjaro MT Kenia gletsjers smelten, rivieren vallen droog, massamigratie, en jij denkt dat alles goed komt 🤣',
#   'ruudvz',
#   0,
#   0],
#  [datetime.datetime(2023, 4, 23, 13, 2, 50, tzinfo=datetime.timezone.utc),
#   1650123062187098113,
#   '@deheij @telegraaf Daarom heeft het WEF de Corona epidemie ontwikkelt 🤣',
#   'ruudvz',
#   0,
#   0],
#  ...]

# %%
tweet_df = pd.DataFrame(tweet_data, columns=['date', 'id', 'content', 'username', 'like', 'retweet'])

# %%
tweet_df
# Out:
#                            date                   id  \
# 0     2023-04-30 22:10:43+00:00  1652797654613610497
# 1     2023-04-30 21:19:49+00:00  1652784845901135874
# 2     2023-04-30 20:41:24+00:00  1652775180400316419
# 3     2023-04-30 20:40:36+00:00  1652774980143263747
# 4     2023-04-30 20:18:00+00:00  1652769288917250048
# ...                         ...                  ...
# 16990 2023-01-11 13:31:49+00:00  1613166793790464000
# 16991 2023-01-11 13:25:55+00:00  1613165309094989824
# 16992 2023-01-11 13:14:20+00:00  1613162395605639170
# 16993 2023-01-11 13:04:46+00:00  1613159985403371521
# 16994 2023-01-11 12:55:22+00:00  1613157621178966017
#
#                                                  content         username  \
# 0                  Sacramento asking for water 🤣\n\n#NBA         Emanzi20
# 1                            @Maziku07 Unanipanga sana 🤣          gcngo88
# 2      @nj3ry @ItsDevMutai I'm selling hope here. Don...        AbadoJack
# 3      @Schwarzenegger Why are you playing with food?...      BabiesLoyal
# 4                                                      🤣        BenonGowa
# ...                                                  ...              ...
# 16990                              @cycy_bae Yimpe chu 🤣       Emmykawaja
# 16991                                                  🤣        BenonGowa
# 16992                                               😂🤣😂🤣      betyalarcon
# 16993                             @AFTVMedia 4 points 😂🤣  ChairmanNyanzi1
# 16994                   @bhadgurlrih anajifanya layman 🤣         letmanbe
#
#        like  retweet
# 0         4        1
# 1         0        0
# 2         2        0
# 3         0        0
# 4         1        0
# ...     ...      ...
# 16990     0        0
# 16991     0        0
# 16992     2        0
# 16993     0        0
# 16994     1        0
#
# [16995 rows x 6 columns]

# %%
from datetime import datetime

# %%
# Convert the 'Date' column to timezone-unaware datetime so as to save in excel
tweet_df['date'] = tweet_df['date'].dt.tz_convert(None)

# %%
tweet_df
# Out:
#                      date                   id  \
# 0     2023-04-30 22:10:43  1652797654613610497
# 1     2023-04-30 21:19:49  1652784845901135874
# 2     2023-04-30 20:41:24  1652775180400316419
# 3     2023-04-30 20:40:36  1652774980143263747
# 4     2023-04-30 20:18:00  1652769288917250048
# ...                   ...                  ...
# 16990 2023-01-11 13:31:49  1613166793790464000
# 16991 2023-01-11 13:25:55  1613165309094989824
# 16992 2023-01-11 13:14:20  1613162395605639170
# 16993 2023-01-11 13:04:46  1613159985403371521
# 16994 2023-01-11 12:55:22  1613157621178966017
#
#                                                  content         username  \
# 0                  Sacramento asking for water 🤣\n\n#NBA         Emanzi20
# 1                            @Maziku07 Unanipanga sana 🤣          gcngo88
# 2      @nj3ry @ItsDevMutai I'm selling hope here. Don...        AbadoJack
# 3      @Schwarzenegger Why are you playing with food?...      BabiesLoyal
# 4                                                      🤣        BenonGowa
# ...                                                  ...              ...
# 16990                              @cycy_bae Yimpe chu 🤣       Emmykawaja
# 16991                                                  🤣        BenonGowa
# 16992                                               😂🤣😂🤣      betyalarcon
# 16993                             @AFTVMedia 4 points 😂🤣  ChairmanNyanzi1
# 16994                   @bhadgurlrih anajifanya layman 🤣         letmanbe
#
#        like  retweet
# 0         4        1
# 1         0        0
# 2         2        0
# 3         0        0
# 4         1        0
# ...     ...      ...
# 16990     0        0
# 16991     0        0
# 16992     2        0
# 16993     0        0
# 16994     1        0
#
# [16995 rows x 6 columns]

# %%
# Saving the DataFrame to an Excel file
tweet_df.to_excel('C:/Users/Alex/OneDrive/Desktop/tweets_mombasa.xlsx', index=False)
